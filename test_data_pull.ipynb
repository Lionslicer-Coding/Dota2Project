# %%
import requests
import pandas as pd
import json

# %%
match_ids = requests.get('https://api.opendota.com/api/publicMatches?api_key=72d85202-722b-40f3-9bee-1ded0440a148')
match_ids.json()
# Out:
# [{'match_id': 5709200803,
#   'match_seq_num': 4802285981,
#   'radiant_win': False,
#   'start_time': 1605893514,
#   'duration': 580,
#   'avg_mmr': 3041,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 49,
#   'num_rank_tier': 4,
#   'cluster': 132,
#   'radiant_team': '70,11,86,6,120',
#   'dire_team': '14,105,93,39,28'},
#  {'match_id': 5709198100,
#   'match_seq_num': 4802282006,
#   'radiant_win': False,
#   'start_time': 1605893383,
#   'duration': 524,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 29,
#   'num_rank_tier': 2,
#   'cluster': 156,
#   'radiant_team': '11,40,60,6,53',
#   'dire_team': '12,29,63,14,9'},
#  {'match_id': 5709197714,
#   'match_seq_num': 4802280886,
#   'radiant_win': False,
#   'start_time': 1605893364,
#   'duration': 460,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 5,
#   'avg_rank_tier': 50,
#   'num_rank_tier': 5,
#   'cluster': 186,
#   'radiant_team': '82,83,91,88,19',
#   'dire_team': '28,33,100,47,93'},
#  {'match_id': 5709196819,
#   'match_seq_num': 4802291877,
#   'radiant_win': True,
#   'start_time': 1605893319,
#   'duration': 1005,
#   'avg_mmr': 1216,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 29,
#   'num_rank_tier': 8,
#   'cluster': 184,
#   'radiant_team': '44,121,28,14,106',
#   'dire_team': '6,39,86,20,42'},
#  {'match_id': 5709193008,
#   'match_seq_num': 4802292561,
#   'radiant_win': False,
#   'start_time': 1605893138,
#   'duration': 1334,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 27,
#   'num_rank_tier': 2,
#   'cluster': 192,
#   'radiant_team': '63,46,33,26,96',
#   'dire_team': '16,99,41,37,56'},
#  {'match_id': 5709192212,
#   'match_seq_num': 4802292812,
#   'radiant_win': True,
#   'start_time': 1605893099,
#   'duration': 1446,
#   'avg_mmr': 3519,
#   'num_mmr': 3,
#   'lobby_type': 0,
#   'game_mode': 5,
#   'avg_rank_tier': 48,
#   'num_rank_tier': 7,
#   'cluster': 181,
#   'radiant_team': '30,46,114,39,108',
#   'dire_team': '126,107,35,106,64'},
#  {'match_id': 5709191613,
#   'match_seq_num': 4802292450,
#   'radiant_win': True,
#   'start_time': 1605893075,
#   'duration': 1387,
#   'avg_mmr': 2888,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 42,
#   'num_rank_tier': 5,
#   'cluster': 134,
#   'radiant_team': '85,30,6,53,19',
#   'dire_team': '25,48,9,120,26'},
#  {'match_id': 5709191205,
#   'match_seq_num': 4802290360,
#   'radiant_win': True,
#   'start_time': 1605893055,
#   'duration': 1255,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 29,
#   'num_rank_tier': 7,
#   'cluster': 182,
#   'radiant_team': '83,128,107,80,1',
#   'dire_team': '5,93,59,64,28'},
#  {'match_id': 5709191015,
#   'match_seq_num': 4802291588,
#   'radiant_win': True,
#   'start_time': 1605893047,
#   'duration': 1353,
#   'avg_mmr': 4234,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 3,
#   'avg_rank_tier': 54,
#   'num_rank_tier': 9,
#   'cluster': 227,
#   'radiant_team': '66,45,129,18,21',
#   'dire_team': '29,5,71,44,34'},
#  {'match_id': 5709191011,
#   'match_seq_num': 4802289784,
#   'radiant_win': False,
#   'start_time': 1605893043,
#   'duration': 1264,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 31,
#   'num_rank_tier': 5,
#   'cluster': 187,
#   'radiant_team': '129,30,56,113,41',
#   'dire_team': '107,74,109,119,120'},
#  {'match_id': 5709190919,
#   'match_seq_num': 4802292648,
#   'radiant_win': False,
#   'start_time': 1605893023,
#   'duration': 1432,
#   'avg_mmr': 1667,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 44,
#   'num_rank_tier': 4,
#   'cluster': 251,
#   'radiant_team': '46,44,21,81,3',
#   'dire_team': '10,42,9,104,26'},
#  {'match_id': 5709190712,
#   'match_seq_num': 4802292129,
#   'radiant_win': True,
#   'start_time': 1605893032,
#   'duration': 1421,
#   'avg_mmr': 5455,
#   'num_mmr': 7,
#   'lobby_type': 7,
#   'game_mode': 3,
#   'avg_rank_tier': 80,
#   'num_rank_tier': 10,
#   'cluster': 236,
#   'radiant_team': '84,8,105,104,17',
#   'dire_team': '2,5,76,41,9'},
#  {'match_id': 5709189712,
#   'match_seq_num': 4802291948,
#   'radiant_win': True,
#   'start_time': 1605892973,
#   'duration': 1414,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 23,
#   'num_rank_tier': 4,
#   'cluster': 181,
#   'radiant_team': '45,48,59,51,37',
#   'dire_team': '4,1,26,69,86'},
#  {'match_id': 5709189400,
#   'match_seq_num': 4802283746,
#   'radiant_win': False,
#   'start_time': 1605892969,
#   'duration': 1015,
#   'avg_mmr': 3033,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 53,
#   'num_rank_tier': 5,
#   'cluster': 185,
#   'radiant_team': '9,44,28,101,97',
#   'dire_team': '61,25,87,21,93'},
#  {'match_id': 5709188909,
#   'match_seq_num': 4802277604,
#   'radiant_win': True,
#   'start_time': 1605892944,
#   'duration': 766,
#   'avg_mmr': 3225,
#   'num_mmr': 3,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 46,
#   'num_rank_tier': 8,
#   'cluster': 193,
#   'radiant_team': '50,56,11,12,14',
#   'dire_team': '59,74,27,75,8'},
#  {'match_id': 5709188501,
#   'match_seq_num': 4802289764,
#   'radiant_win': True,
#   'start_time': 1605892923,
#   'duration': 1375,
#   'avg_mmr': 2966,
#   'num_mmr': 3,
#   'lobby_type': 0,
#   'game_mode': 3,
#   'avg_rank_tier': 57,
#   'num_rank_tier': 5,
#   'cluster': 236,
#   'radiant_team': '93,46,19,85,86',
#   'dire_team': '8,104,75,64,22'},
#  {'match_id': 5709188204,
#   'match_seq_num': 4802277594,
#   'radiant_win': False,
#   'start_time': 1605892908,
#   'duration': 781,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 42,
#   'num_rank_tier': 8,
#   'cluster': 186,
#   'radiant_team': '75,99,11,105,8',
#   'dire_team': '56,110,119,22,54'},
#  {'match_id': 5709188101,
#   'match_seq_num': 4802288493,
#   'radiant_win': True,
#   'start_time': 1605892898,
#   'duration': 1321,
#   'avg_mmr': 3299,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 50,
#   'num_rank_tier': 5,
#   'cluster': 251,
#   'radiant_team': '42,39,4,22,91',
#   'dire_team': '27,79,126,104,8'},
#  {'match_id': 5709187914,
#   'match_seq_num': 4802290466,
#   'radiant_win': False,
#   'start_time': 1605892888,
#   'duration': 1464,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 32,
#   'num_rank_tier': 2,
#   'cluster': 251,
#   'radiant_team': '107,28,36,95,43',
#   'dire_team': '42,120,68,18,14'},
#  {'match_id': 5709187910,
#   'match_seq_num': 4802291739,
#   'radiant_win': True,
#   'start_time': 1605892882,
#   'duration': 1456,
#   'avg_mmr': 3520,
#   'num_mmr': 7,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 57,
#   'num_rank_tier': 8,
#   'cluster': 184,
#   'radiant_team': '67,129,100,4,22',
#   'dire_team': '44,14,69,13,35'},
#  {'match_id': 5709187818,
#   'match_seq_num': 4802286938,
#   'radiant_win': True,
#   'start_time': 1605892887,
#   'duration': 1289,
#   'avg_mmr': 4364,
#   'num_mmr': 6,
#   'lobby_type': 7,
#   'game_mode': 3,
#   'avg_rank_tier': 78,
#   'num_rank_tier': 8,
#   'cluster': 236,
#   'radiant_team': '47,69,4,64,48',
#   'dire_team': '26,11,29,84,109'},
#  {'match_id': 5709187704,
#   'match_seq_num': 4802290337,
#   'radiant_win': False,
#   'start_time': 1605892883,
#   'duration': 1410,
#   'avg_mmr': 2899,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 43,
#   'num_rank_tier': 3,
#   'cluster': 133,
#   'radiant_team': '9,19,11,48,98',
#   'dire_team': '113,23,62,105,7'},
#  {'match_id': 5709187403,
#   'match_seq_num': 4802292000,
#   'radiant_win': True,
#   'start_time': 1605892847,
#   'duration': 1557,
#   'avg_mmr': 3682,
#   'num_mmr': 2,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 53,
#   'num_rank_tier': 4,
#   'cluster': 193,
#   'radiant_team': '104,36,47,96,2',
#   'dire_team': '81,111,70,19,97'},
#  {'match_id': 5709187301,
#   'match_seq_num': 4802291667,
#   'radiant_win': False,
#   'start_time': 1605892873,
#   'duration': 1555,
#   'avg_mmr': 3104,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 51,
#   'num_rank_tier': 6,
#   'cluster': 184,
#   'radiant_team': '128,32,70,40,49',
#   'dire_team': '63,4,28,37,8'},
#  {'match_id': 5709187109,
#   'match_seq_num': 4802291865,
#   'radiant_win': False,
#   'start_time': 1605892862,
#   'duration': 1560,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 21,
#   'num_rank_tier': 4,
#   'cluster': 182,
#   'radiant_team': '36,8,99,30,53',
#   'dire_team': '41,104,5,84,56'},
#  {'match_id': 5709187006,
#   'match_seq_num': 4802290942,
#   'radiant_win': True,
#   'start_time': 1605892853,
#   'duration': 1419,
#   'avg_mmr': 2002,
#   'num_mmr': 2,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 45,
#   'num_rank_tier': 7,
#   'cluster': 135,
#   'radiant_team': '44,69,64,86,112',
#   'dire_team': '12,21,18,31,19'},
#  {'match_id': 5709186815,
#   'match_seq_num': 4802292168,
#   'radiant_win': False,
#   'start_time': 1605892842,
#   'duration': 1574,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 13,
#   'num_rank_tier': 2,
#   'cluster': 131,
#   'radiant_team': '6,90,48,62,95',
#   'dire_team': '84,61,18,70,109'},
#  {'match_id': 5709186418,
#   'match_seq_num': 4802292753,
#   'radiant_win': True,
#   'start_time': 1605892828,
#   'duration': 1600,
#   'avg_mmr': 2747,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 33,
#   'num_rank_tier': 4,
#   'cluster': 186,
#   'radiant_team': '75,23,18,53,108',
#   'dire_team': '14,41,90,2,74'},
#  {'match_id': 5709186416,
#   'match_seq_num': 4802291936,
#   'radiant_win': True,
#   'start_time': 1605892827,
#   'duration': 1510,
#   'avg_mmr': 3434,
#   'num_mmr': 3,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 52,
#   'num_rank_tier': 7,
#   'cluster': 188,
#   'radiant_team': '76,86,68,2,81',
#   'dire_team': '114,49,48,14,128'},
#  {'match_id': 5709186318,
#   'match_seq_num': 4802292947,
#   'radiant_win': True,
#   'start_time': 1605892823,
#   'duration': 1632,
#   'avg_mmr': 3704,
#   'num_mmr': 5,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 53,
#   'num_rank_tier': 7,
#   'cluster': 183,
#   'radiant_team': '56,2,6,49,101',
#   'dire_team': '19,47,102,87,36'},
#  {'match_id': 5709186316,
#   'match_seq_num': 4802292267,
#   'radiant_win': False,
#   'start_time': 1605892822,
#   'duration': 1548,
#   'avg_mmr': 1099,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 18,
#   'num_rank_tier': 2,
#   'cluster': 181,
#   'radiant_team': '95,70,6,8,67',
#   'dire_team': '4,15,104,1,62'},
#  {'match_id': 5709186109,
#   'match_seq_num': 4802290668,
#   'radiant_win': True,
#   'start_time': 1605892814,
#   'duration': 1569,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 39,
#   'num_rank_tier': 2,
#   'cluster': 191,
#   'radiant_team': '109,112,84,83,74',
#   'dire_team': '59,42,92,99,102'},
#  {'match_id': 5709186011,
#   'match_seq_num': 4802292774,
#   'radiant_win': False,
#   'start_time': 1605892812,
#   'duration': 1604,
#   'avg_mmr': 3044,
#   'num_mmr': 4,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 52,
#   'num_rank_tier': 6,
#   'cluster': 251,
#   'radiant_team': '13,17,26,128,18',
#   'dire_team': '126,110,119,93,29'},
#  {'match_id': 5709185910,
#   'match_seq_num': 4802293238,
#   'radiant_win': True,
#   'start_time': 1605892797,
#   'duration': 1639,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 21,
#   'num_rank_tier': 2,
#   'cluster': 201,
#   'radiant_team': '6,71,114,99,83',
#   'dire_team': '67,128,21,10,54'},
#  {'match_id': 5709185711,
#   'match_seq_num': 4802288070,
#   'radiant_win': True,
#   'start_time': 1605892797,
#   'duration': 1377,
#   'avg_mmr': 3599,
#   'num_mmr': 3,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 40,
#   'num_rank_tier': 4,
#   'cluster': 187,
#   'radiant_team': '103,20,114,2,93',
#   'dire_team': '95,27,34,11,129'},
#  {'match_id': 5709185708,
#   'match_seq_num': 4802292689,
#   'radiant_win': False,
#   'start_time': 1605892787,
#   'duration': 1612,
#   'avg_mmr': 2073,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 35,
#   'num_rank_tier': 2,
#   'cluster': 122,
#   'radiant_team': '129,22,67,5,31',
#   'dire_team': '8,112,98,14,21'},
#  {'match_id': 5709185514,
#   'match_seq_num': 4802289308,
#   'radiant_win': True,
#   'start_time': 1605892782,
#   'duration': 1366,
#   'avg_mmr': 3468,
#   'num_mmr': 4,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 56,
#   'num_rank_tier': 9,
#   'cluster': 154,
#   'radiant_team': '47,14,12,39,96',
#   'dire_team': '29,40,17,84,44'},
#  {'match_id': 5709185503,
#   'match_seq_num': 4802288371,
#   'radiant_win': True,
#   'start_time': 1605892789,
#   'duration': 1461,
#   'avg_mmr': 2930,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 38,
#   'num_rank_tier': 8,
#   'cluster': 187,
#   'radiant_team': '14,84,28,63,95',
#   'dire_team': '41,111,53,121,74'},
#  {'match_id': 5709185501,
#   'match_seq_num': 4802286182,
#   'radiant_win': False,
#   'start_time': 1605892787,
#   'duration': 1335,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 17,
#   'num_rank_tier': 2,
#   'cluster': 185,
#   'radiant_team': '22,84,8,44,7',
#   'dire_team': '47,41,21,129,48'},
#  {'match_id': 5709185118,
#   'match_seq_num': 4802288696,
#   'radiant_win': False,
#   'start_time': 1605892754,
#   'duration': 1488,
#   'avg_mmr': 3983,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 52,
#   'num_rank_tier': 5,
#   'cluster': 251,
#   'radiant_team': '8,26,4,76,121',
#   'dire_team': '62,106,86,1,29'},
#  {'match_id': 5709184701,
#   'match_seq_num': 4802290472,
#   'radiant_win': True,
#   'start_time': 1605892738,
#   'duration': 1596,
#   'avg_mmr': 3061,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 51,
#   'num_rank_tier': 6,
#   'cluster': 187,
#   'radiant_team': '112,10,35,30,104',
#   'dire_team': '9,93,99,26,39'},
#  {'match_id': 5709184512,
#   'match_seq_num': 4802288799,
#   'radiant_win': False,
#   'start_time': 1605892737,
#   'duration': 1474,
#   'avg_mmr': 3937,
#   'num_mmr': 6,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 70,
#   'num_rank_tier': 6,
#   'cluster': 123,
#   'radiant_team': '64,8,104,111,74',
#   'dire_team': '46,14,18,62,91'},
#  {'match_id': 5709184207,
#   'match_seq_num': 4802292632,
#   'radiant_win': True,
#   'start_time': 1605892732,
#   'duration': 1713,
#   'avg_mmr': 1803,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 22,
#   'num_rank_tier': 3,
#   'cluster': 183,
#   'radiant_team': '64,119,14,56,48',
#   'dire_team': '67,5,28,126,30'},
#  {'match_id': 5709184018,
#   'match_seq_num': 4802292779,
#   'radiant_win': False,
#   'start_time': 1605892718,
#   'duration': 1665,
#   'avg_mmr': 3181,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 53,
#   'num_rank_tier': 5,
#   'cluster': 123,
#   'radiant_team': '11,95,27,97,71',
#   'dire_team': '93,81,84,74,110'},
#  {'match_id': 5709183906,
#   'match_seq_num': 4802289317,
#   'radiant_win': True,
#   'start_time': 1605892708,
#   'duration': 1567,
#   'avg_mmr': 3556,
#   'num_mmr': 2,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 50,
#   'num_rank_tier': 4,
#   'cluster': 181,
#   'radiant_team': '67,11,31,51,28',
#   'dire_team': '77,65,37,46,93'},
#  {'match_id': 5709183700,
#   'match_seq_num': 4802287451,
#   'radiant_win': True,
#   'start_time': 1605892703,
#   'duration': 1184,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 43,
#   'num_rank_tier': 3,
#   'cluster': 214,
#   'radiant_team': '11,7,59,31,81',
#   'dire_team': '26,6,86,104,41'},
#  {'match_id': 5709183613,
#   'match_seq_num': 4802291517,
#   'radiant_win': False,
#   'start_time': 1605892702,
#   'duration': 1647,
#   'avg_mmr': 1141,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 28,
#   'num_rank_tier': 2,
#   'cluster': 153,
#   'radiant_team': '74,19,105,2,12',
#   'dire_team': '91,9,18,35,29'},
#  {'match_id': 5709183606,
#   'match_seq_num': 4802290607,
#   'radiant_win': False,
#   'start_time': 1605892692,
#   'duration': 1644,
#   'avg_mmr': 3379,
#   'num_mmr': 2,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 39,
#   'num_rank_tier': 4,
#   'cluster': 181,
#   'radiant_team': '51,9,47,22,107',
#   'dire_team': '105,19,94,14,11'},
#  {'match_id': 5709183409,
#   'match_seq_num': 4802292747,
#   'radiant_win': False,
#   'start_time': 1605892673,
#   'duration': 1748,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 13,
#   'num_rank_tier': 2,
#   'cluster': 184,
#   'radiant_team': '113,119,58,69,8',
#   'dire_team': '36,33,48,10,16'},
#  {'match_id': 5709183302,
#   'match_seq_num': 4802291655,
#   'radiant_win': True,
#   'start_time': 1605892687,
#   'duration': 1709,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 34,
#   'num_rank_tier': 6,
#   'cluster': 132,
#   'radiant_team': '42,5,63,33,108',
#   'dire_team': '91,101,18,74,2'},
#  {'match_id': 5709183217,
#   'match_seq_num': 4802291994,
#   'radiant_win': False,
#   'start_time': 1605892676,
#   'duration': 1766,
#   'avg_mmr': 4416,
#   'num_mmr': 4,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 69,
#   'num_rank_tier': 6,
#   'cluster': 153,
#   'radiant_team': '60,34,44,72,6',
#   'dire_team': '59,69,81,23,45'},
#  {'match_id': 5709182717,
#   'match_seq_num': 4802286107,
#   'radiant_win': True,
#   'start_time': 1605892659,
#   'duration': 1465,
#   'avg_mmr': 3047,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 44,
#   'num_rank_tier': 4,
#   'cluster': 187,
#   'radiant_team': '51,92,54,45,37',
#   'dire_team': '8,105,28,68,114'},
#  {'match_id': 5709182514,
#   'match_seq_num': 4802287606,
#   'radiant_win': True,
#   'start_time': 1605892648,
#   'duration': 1473,
#   'avg_mmr': 3104,
#   'num_mmr': 3,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 71,
#   'num_rank_tier': 6,
#   'cluster': 182,
#   'radiant_team': '54,29,64,11,100',
#   'dire_team': '44,84,97,19,128'},
#  {'match_id': 5709182509,
#   'match_seq_num': 4802292199,
#   'radiant_win': False,
#   'start_time': 1605892643,
#   'duration': 1774,
#   'avg_mmr': 1549,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 32,
#   'num_rank_tier': 7,
#   'cluster': 236,
#   'radiant_team': '1,25,99,74,79',
#   'dire_team': '6,108,21,5,14'},
#  {'match_id': 5709182218,
#   'match_seq_num': 4802288028,
#   'radiant_win': False,
#   'start_time': 1605892637,
#   'duration': 1570,
#   'avg_mmr': 1880,
#   'num_mmr': 4,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 39,
#   'num_rank_tier': 5,
#   'cluster': 186,
#   'radiant_team': '74,105,93,19,94',
#   'dire_team': '97,9,54,8,80'},
#  {'match_id': 5709182002,
#   'match_seq_num': 4802284438,
#   'radiant_win': False,
#   'start_time': 1605892587,
#   'duration': 1408,
#   'avg_mmr': 3056,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 54,
#   'num_rank_tier': 3,
#   'cluster': 122,
#   'radiant_team': '35,76,54,129,91',
#   'dire_team': '10,104,20,23,101'},
#  {'match_id': 5709181900,
#   'match_seq_num': 4802293062,
#   'radiant_win': False,
#   'start_time': 1605892607,
#   'duration': 1851,
#   'avg_mmr': 1863,
#   'num_mmr': 2,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 33,
#   'num_rank_tier': 3,
#   'cluster': 137,
#   'radiant_team': '65,63,47,93,17',
#   'dire_team': '5,14,25,75,8'},
#  {'match_id': 5709181712,
#   'match_seq_num': 4802292884,
#   'radiant_win': False,
#   'start_time': 1605892613,
#   'duration': 1791,
#   'avg_mmr': 2136,
#   'num_mmr': 2,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 37,
#   'num_rank_tier': 4,
#   'cluster': 123,
#   'radiant_team': '14,85,73,129,44',
#   'dire_team': '6,61,86,32,83'},
#  {'match_id': 5709181617,
#   'match_seq_num': 4802286135,
#   'radiant_win': True,
#   'start_time': 1605892602,
#   'duration': 1499,
#   'avg_mmr': 2275,
#   'num_mmr': 3,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 52,
#   'num_rank_tier': 6,
#   'cluster': 182,
#   'radiant_team': '46,126,101,67,85',
#   'dire_team': '51,28,12,112,74'},
#  {'match_id': 5709181514,
#   'match_seq_num': 4802291407,
#   'radiant_win': False,
#   'start_time': 1605892603,
#   'duration': 1736,
#   'avg_mmr': 606,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 28,
#   'num_rank_tier': 6,
#   'cluster': 186,
#   'radiant_team': '74,26,2,54,100',
#   'dire_team': '21,121,8,22,50'},
#  {'match_id': 5709181505,
#   'match_seq_num': 4802286777,
#   'radiant_win': False,
#   'start_time': 1605892582,
#   'duration': 1511,
#   'avg_mmr': 2721,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 25,
#   'num_rank_tier': 3,
#   'cluster': 182,
#   'radiant_team': '2,21,6,26,82',
#   'dire_team': '30,35,111,63,59'},
#  {'match_id': 5709181400,
#   'match_seq_num': 4802292645,
#   'radiant_win': True,
#   'start_time': 1605892598,
#   'duration': 1781,
#   'avg_mmr': 4804,
#   'num_mmr': 4,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 80,
#   'num_rank_tier': 8,
#   'cluster': 121,
#   'radiant_team': '51,129,25,18,45',
#   'dire_team': '44,3,81,9,126'},
#  {'match_id': 5709181301,
#   'match_seq_num': 4802287170,
#   'radiant_win': False,
#   'start_time': 1605892582,
#   'duration': 1585,
#   'avg_mmr': 2655,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 45,
#   'num_rank_tier': 3,
#   'cluster': 134,
#   'radiant_team': '53,14,6,93,31',
#   'dire_team': '51,50,40,48,74'},
#  {'match_id': 5709181214,
#   'match_seq_num': 4802286542,
#   'radiant_win': True,
#   'start_time': 1605892587,
#   'duration': 1540,
#   'avg_mmr': 3514,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 27,
#   'num_rank_tier': 3,
#   'cluster': 137,
#   'radiant_team': '114,16,32,106,18',
#   'dire_team': '76,81,70,40,41'},
#  {'match_id': 5709181213,
#   'match_seq_num': 4802292733,
#   'radiant_win': True,
#   'start_time': 1605892582,
#   'duration': 1853,
#   'avg_mmr': 3433,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 35,
#   'num_rank_tier': 6,
#   'cluster': 184,
#   'radiant_team': '2,93,36,75,84',
#   'dire_team': '119,107,50,18,23'},
#  {'match_id': 5709180919,
#   'match_seq_num': 4802283506,
#   'radiant_win': False,
#   'start_time': 1605892577,
#   'duration': 1469,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 12,
#   'num_rank_tier': 3,
#   'cluster': 188,
#   'radiant_team': '91,28,43,26,63',
#   'dire_team': '37,113,32,30,128'},
#  {'match_id': 5709180710,
#   'match_seq_num': 4802292222,
#   'radiant_win': False,
#   'start_time': 1605892567,
#   'duration': 1903,
#   'avg_mmr': 4351,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 49,
#   'num_rank_tier': 2,
#   'cluster': 152,
#   'radiant_team': '18,21,76,12,95',
#   'dire_team': '41,64,111,35,68'},
#  {'match_id': 5709180708,
#   'match_seq_num': 4802291477,
#   'radiant_win': False,
#   'start_time': 1605892566,
#   'duration': 1821,
#   'avg_mmr': 3176,
#   'num_mmr': 5,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 54,
#   'num_rank_tier': 5,
#   'cluster': 135,
#   'radiant_team': '4,74,9,70,5',
#   'dire_team': '97,25,57,30,32'},
#  {'match_id': 5709180705,
#   'match_seq_num': 4802289089,
#   'radiant_win': False,
#   'start_time': 1605892562,
#   'duration': 1617,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 31,
#   'num_rank_tier': 2,
#   'cluster': 251,
#   'radiant_team': '14,97,121,105,70',
#   'dire_team': '31,48,54,7,98'},
#  {'match_id': 5709180702,
#   'match_seq_num': 4802286828,
#   'radiant_win': True,
#   'start_time': 1605892553,
#   'duration': 1584,
#   'avg_mmr': 1507,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 33,
#   'num_rank_tier': 2,
#   'cluster': 241,
#   'radiant_team': '84,62,85,93,99',
#   'dire_team': '32,120,41,25,110'},
#  {'match_id': 5709180619,
#   'match_seq_num': 4802268374,
#   'radiant_win': False,
#   'start_time': 1605892563,
#   'duration': 659,
#   'avg_mmr': 3105,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 34,
#   'num_rank_tier': 5,
#   'cluster': 151,
#   'radiant_team': '111,74,17,95,14',
#   'dire_team': '4,113,110,26,99'},
#  {'match_id': 5709180409,
#   'match_seq_num': 4802291115,
#   'radiant_win': True,
#   'start_time': 1605892553,
#   'duration': 1732,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 38,
#   'num_rank_tier': 3,
#   'cluster': 241,
#   'radiant_team': '114,21,64,16,44',
#   'dire_team': '28,74,70,68,14'},
#  {'match_id': 5709180408,
#   'match_seq_num': 4802290144,
#   'radiant_win': True,
#   'start_time': 1605892553,
#   'duration': 1777,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 15,
#   'num_rank_tier': 4,
#   'cluster': 182,
#   'radiant_team': '71,6,25,22,129',
#   'dire_team': '14,58,114,30,84'},
#  {'match_id': 5709180407,
#   'match_seq_num': 4802292085,
#   'radiant_win': True,
#   'start_time': 1605892553,
#   'duration': 1807,
#   'avg_mmr': 3476,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 3,
#   'avg_rank_tier': 48,
#   'num_rank_tier': 3,
#   'cluster': 231,
#   'radiant_team': '6,28,113,83,64',
#   'dire_team': '14,43,2,29,93'},
#  {'match_id': 5709180406,
#   'match_seq_num': 4802285251,
#   'radiant_win': True,
#   'start_time': 1605892552,
#   'duration': 1483,
#   'avg_mmr': 2777,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 39,
#   'num_rank_tier': 5,
#   'cluster': 155,
#   'radiant_team': '25,84,88,41,21',
#   'dire_team': '26,5,44,67,19'},
#  {'match_id': 5709180401,
#   'match_seq_num': 4802291603,
#   'radiant_win': False,
#   'start_time': 1605892552,
#   'duration': 1819,
#   'avg_mmr': 2784,
#   'num_mmr': 4,
#   'lobby_type': 7,
#   'game_mode': 3,
#   'avg_rank_tier': 38,
#   'num_rank_tier': 8,
#   'cluster': 227,
#   'radiant_team': '110,76,44,49,30',
#   'dire_team': '27,47,10,2,31'},
#  {'match_id': 5709180400,
#   'match_seq_num': 4802290438,
#   'radiant_win': True,
#   'start_time': 1605892552,
#   'duration': 1779,
#   'avg_mmr': 3597,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 50,
#   'num_rank_tier': 2,
#   'cluster': 151,
#   'radiant_team': '119,8,91,85,35',
#   'dire_team': '67,100,9,90,69'},
#  {'match_id': 5709180317,
#   'match_seq_num': 4802281201,
#   'radiant_win': True,
#   'start_time': 1605892546,
#   'duration': 1351,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 45,
#   'num_rank_tier': 5,
#   'cluster': 187,
#   'radiant_team': '83,63,41,39,59',
#   'dire_team': '99,106,110,21,1'},
#  {'match_id': 5709180316,
#   'match_seq_num': 4802292708,
#   'radiant_win': False,
#   'start_time': 1605892548,
#   'duration': 1895,
#   'avg_mmr': 1595,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 22,
#   'num_rank_tier': 4,
#   'cluster': 193,
#   'radiant_team': '47,32,84,87,22',
#   'dire_team': '37,18,108,74,10'},
#  {'match_id': 5709180314,
#   'match_seq_num': 4802293097,
#   'radiant_win': True,
#   'start_time': 1605892548,
#   'duration': 1919,
#   'avg_mmr': 1773,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 30,
#   'num_rank_tier': 3,
#   'cluster': 251,
#   'radiant_team': '47,19,120,26,42',
#   'dire_team': '79,8,100,1,108'},
#  {'match_id': 5709180102,
#   'match_seq_num': 4802288836,
#   'radiant_win': True,
#   'start_time': 1605892539,
#   'duration': 1658,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 31,
#   'num_rank_tier': 4,
#   'cluster': 186,
#   'radiant_team': '45,44,21,104,26',
#   'dire_team': '53,65,41,5,59'},
#  {'match_id': 5709180100,
#   'match_seq_num': 4802289274,
#   'radiant_win': False,
#   'start_time': 1605892538,
#   'duration': 1759,
#   'avg_mmr': 2385,
#   'num_mmr': 2,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 49,
#   'num_rank_tier': 5,
#   'cluster': 134,
#   'radiant_team': '100,67,9,105,70',
#   'dire_team': '56,80,87,113,129'},
#  {'match_id': 5709179906,
#   'match_seq_num': 4802282021,
#   'radiant_win': False,
#   'start_time': 1605892533,
#   'duration': 1380,
#   'avg_mmr': 4404,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 68,
#   'num_rank_tier': 5,
#   'cluster': 152,
#   'radiant_team': '44,2,52,93,19',
#   'dire_team': '63,128,86,45,7'},
#  {'match_id': 5709179900,
#   'match_seq_num': 4802292314,
#   'radiant_win': True,
#   'start_time': 1605892529,
#   'duration': 1899,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 49,
#   'num_rank_tier': 3,
#   'cluster': 251,
#   'radiant_team': '84,83,129,41,74',
#   'dire_team': '14,40,1,126,21'},
#  {'match_id': 5709179817,
#   'match_seq_num': 4802291796,
#   'radiant_win': False,
#   'start_time': 1605892511,
#   'duration': 1875,
#   'avg_mmr': 3438,
#   'num_mmr': 3,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 44,
#   'num_rank_tier': 3,
#   'cluster': 152,
#   'radiant_team': '129,18,30,70,10',
#   'dire_team': '71,47,98,29,54'},
#  {'match_id': 5709179702,
#   'match_seq_num': 4802278334,
#   'radiant_win': True,
#   'start_time': 1605892518,
#   'duration': 1194,
#   'avg_mmr': 2780,
#   'num_mmr': 3,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 43,
#   'num_rank_tier': 6,
#   'cluster': 181,
#   'radiant_team': '2,8,30,9,56',
#   'dire_team': '55,35,1,31,28'},
#  {'match_id': 5709179508,
#   'match_seq_num': 4802288846,
#   'radiant_win': True,
#   'start_time': 1605892513,
#   'duration': 1702,
#   'avg_mmr': 4138,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 37,
#   'num_rank_tier': 2,
#   'cluster': 193,
#   'radiant_team': '6,75,14,126,104',
#   'dire_team': '109,34,65,21,101'},
#  {'match_id': 5709179507,
#   'match_seq_num': 4802290669,
#   'radiant_win': True,
#   'start_time': 1605892511,
#   'duration': 1776,
#   'avg_mmr': 1450,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 3,
#   'avg_rank_tier': 22,
#   'num_rank_tier': 2,
#   'cluster': 192,
#   'radiant_team': '93,42,32,10,68',
#   'dire_team': '31,28,37,71,15'},
#  {'match_id': 5709179418,
#   'match_seq_num': 4802276051,
#   'radiant_win': True,
#   'start_time': 1605892508,
#   'duration': 1002,
#   'avg_mmr': 3148,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 34,
#   'num_rank_tier': 4,
#   'cluster': 187,
#   'radiant_team': '113,86,30,99,14',
#   'dire_team': '93,11,50,64,57'},
#  {'match_id': 5709179407,
#   'match_seq_num': 4802290672,
#   'radiant_win': False,
#   'start_time': 1605892508,
#   'duration': 1808,
#   'avg_mmr': 3101,
#   'num_mmr': 5,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 48,
#   'num_rank_tier': 8,
#   'cluster': 193,
#   'radiant_team': '75,56,112,44,19',
#   'dire_team': '6,20,7,99,21'},
#  {'match_id': 5709179305,
#   'match_seq_num': 4802276436,
#   'radiant_win': True,
#   'start_time': 1605892503,
#   'duration': 1009,
#   'avg_mmr': 4278,
#   'num_mmr': 3,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 64,
#   'num_rank_tier': 3,
#   'cluster': 137,
#   'radiant_team': '128,10,104,19,6',
#   'dire_team': '1,76,28,50,9'},
#  {'match_id': 5709179203,
#   'match_seq_num': 4802292940,
#   'radiant_win': True,
#   'start_time': 1605892498,
#   'duration': 1910,
#   'avg_mmr': 1466,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 32,
#   'num_rank_tier': 3,
#   'cluster': 203,
#   'radiant_team': '2,94,12,5,50',
#   'dire_team': '8,87,22,101,108'},
#  {'match_id': 5709179110,
#   'match_seq_num': 4802292806,
#   'radiant_win': True,
#   'start_time': 1605892482,
#   'duration': 1986,
#   'avg_mmr': 3138,
#   'num_mmr': 3,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 48,
#   'num_rank_tier': 3,
#   'cluster': 251,
#   'radiant_team': '39,71,97,94,67',
#   'dire_team': '44,20,17,108,18'},
#  {'match_id': 5709179104,
#   'match_seq_num': 4802289115,
#   'radiant_win': False,
#   'start_time': 1605892473,
#   'duration': 1769,
#   'avg_mmr': 3125,
#   'num_mmr': 2,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 61,
#   'num_rank_tier': 3,
#   'cluster': 251,
#   'radiant_team': '48,67,84,128,9',
#   'dire_team': '97,31,100,54,10'},
#  {'match_id': 5709178819,
#   'match_seq_num': 4802291194,
#   'radiant_win': True,
#   'start_time': 1605892482,
#   'duration': 1836,
#   'avg_mmr': 1951,
#   'num_mmr': 1,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 27,
#   'num_rank_tier': 2,
#   'cluster': 251,
#   'radiant_team': '30,71,4,96,14',
#   'dire_team': '21,38,18,44,87'},
#  {'match_id': 5709178817,
#   'match_seq_num': 4802281926,
#   'radiant_win': True,
#   'start_time': 1605892482,
#   'duration': 1450,
#   'avg_mmr': 3217,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 22,
#   'avg_rank_tier': 33,
#   'num_rank_tier': 2,
#   'cluster': 193,
#   'radiant_team': '2,8,5,26,23',
#   'dire_team': '50,48,101,84,61'},
#  {'match_id': 5709178813,
#   'match_seq_num': 4802289250,
#   'radiant_win': False,
#   'start_time': 1605892477,
#   'duration': 1832,
#   'avg_mmr': 578,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 22,
#   'num_rank_tier': 2,
#   'cluster': 188,
#   'radiant_team': '75,78,104,99,1',
#   'dire_team': '42,28,6,95,40'},
#  {'match_id': 5709178811,
#   'match_seq_num': 4802292311,
#   'radiant_win': False,
#   'start_time': 1605892478,
#   'duration': 1952,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 42,
#   'num_rank_tier': 5,
#   'cluster': 188,
#   'radiant_team': '95,126,18,64,30',
#   'dire_team': '26,31,46,99,1'},
#  {'match_id': 5709178807,
#   'match_seq_num': 4802286333,
#   'radiant_win': True,
#   'start_time': 1605892473,
#   'duration': 1634,
#   'avg_mmr': None,
#   'num_mmr': None,
#   'lobby_type': 7,
#   'game_mode': 22,
#   'avg_rank_tier': 22,
#   'num_rank_tier': 4,
#   'cluster': 182,
#   'radiant_team': '17,44,101,20,6',
#   'dire_team': '74,81,114,27,11'},
#  {'match_id': 5709178719,
#   'match_seq_num': 4802283136,
#   'radiant_win': False,
#   'start_time': 1605892471,
#   'duration': 1525,
#   'avg_mmr': 2221,
#   'num_mmr': 1,
#   'lobby_type': 0,
#   'game_mode': 4,
#   'avg_rank_tier': 35,
#   'num_rank_tier': 4,
#   'cluster': 188,
#   'radiant_team': '54,40,57,18,73',
#   'dire_team': '5,107,51,39,56'}]

# %%
match_ids.json()[0]
# Out:
# {'match_id': 5709200803,
#  'match_seq_num': 4802285981,
#  'radiant_win': False,
#  'start_time': 1605893514,
#  'duration': 580,
#  'avg_mmr': 3041,
#  'num_mmr': 2,
#  'lobby_type': 7,
#  'game_mode': 22,
#  'avg_rank_tier': 49,
#  'num_rank_tier': 4,
#  'cluster': 132,
#  'radiant_team': '70,11,86,6,120',
#  'dire_team': '14,105,93,39,28'}

# %%
match_ids2 = requests.get('https://api.opendota.com/api/publicMatches?api_key=72d85202-722b-40f3-9bee-1ded0440a148')

# %%
match_ids2.json()[0]
# Out:
# {'match_id': 5709336415,
#  'match_seq_num': 4802414175,
#  'radiant_win': False,
#  'start_time': 1605900494,
#  'duration': 570,
#  'avg_mmr': 4477,
#  'num_mmr': 3,
#  'lobby_type': 7,
#  'game_mode': 22,
#  'avg_rank_tier': 56,
#  'num_rank_tier': 9,
#  'cluster': 184,
#  'radiant_team': '114,68,8,16,129',
#  'dire_team': '98,120,100,39,73'}

# %%
len(match_ids.json())
# Out:
# 100

# %%
type(match_ids.json())
# Out:
# list

# %%
pd.DataFrame(match_ids.json())
# Out:
#       match_id  match_seq_num  radiant_win  start_time  duration  avg_mmr  \
# 0   5709200803     4802285981        False  1605893514       580   3041.0
# 1   5709198100     4802282006        False  1605893383       524      NaN
# 2   5709197714     4802280886        False  1605893364       460      NaN
# 3   5709196819     4802291877         True  1605893319      1005   1216.0
# 4   5709193008     4802292561        False  1605893138      1334      NaN
# ..         ...            ...          ...         ...       ...      ...
# 95  5709178817     4802281926         True  1605892482      1450   3217.0
# 96  5709178813     4802289250        False  1605892477      1832    578.0
# 97  5709178811     4802292311        False  1605892478      1952      NaN
# 98  5709178807     4802286333         True  1605892473      1634      NaN
# 99  5709178719     4802283136        False  1605892471      1525   2221.0
#
#     num_mmr  lobby_type  game_mode  avg_rank_tier  num_rank_tier  cluster  \
# 0       2.0           7         22             49              4      132
# 1       NaN           0         22             29              2      156
# 2       NaN           0          5             50              5      186
# 3       1.0           0         22             29              8      184
# 4       NaN           0          4             27              2      192
# ..      ...         ...        ...            ...            ...      ...
# 95      1.0           0         22             33              2      193
# 96      1.0           0          4             22              2      188
# 97      NaN           7         22             42              5      188
# 98      NaN           7         22             22              4      182
# 99      1.0           0          4             35              4      188
#
#         radiant_team        dire_team
# 0     70,11,86,6,120  14,105,93,39,28
# 1      11,40,60,6,53    12,29,63,14,9
# 2     82,83,91,88,19  28,33,100,47,93
# 3   44,121,28,14,106    6,39,86,20,42
# 4     63,46,33,26,96   16,99,41,37,56
# ..               ...              ...
# 95       2,8,5,26,23  50,48,101,84,61
# 96    75,78,104,99,1    42,28,6,95,40
# 97   95,126,18,64,30    26,31,46,99,1
# 98    17,44,101,20,6  74,81,114,27,11
# 99    54,40,57,18,73   5,107,51,39,56
#
# [100 rows x 14 columns]
